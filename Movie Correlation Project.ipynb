# %%
# Importing libraries

import pandas as pd
import seaborn as sns
import numpy as np
from dateutil.parser import parse

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#Reading the data

df = pd.read_csv(r'C:\Users\JClark\Downloads\movies.csv')

# %%
#Looking to see if the table returns

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Removing the missing data from the set

df = df.dropna()

# %%
# Checking the Data types of the columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df = df.dropna()

# %%
df[df['released'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df.loc[:, 'year'] = df['released'].str.extract(pat='([0-9]{4})').astype(float)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Extracting the year from the year column because some of the year data was incorect

df['year'] = df['released'].str.extract(pat='([0-9]{4})').astype(float)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#         year                           released  score      votes  \
# ...

# %%
#Changing the columns to ints so that the .0 is removed

df['year'] = pd.to_numeric(df['year'], errors = 'coerce').fillna(0).astype(int)
df['budget'] = pd.to_numeric(df['budget'], errors = 'coerce').fillna(0).astype(int)
df['gross'] = pd.to_numeric(df['gross'], errors = 'coerce').fillna(0).astype(int)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
#Order ing the Data by the Gross Revenue
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
# ...                                          ...    ...        ...   ...
# 272                                     Parasite      R     Horror  1982
# 3203                                  Trojan War  PG-13     Comedy  1997
# 3045                                     Titanic  PG-13      Drama  1997
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 5445                                      Avatar  PG-13     Action  2009
#
#                                released  score    votes         director  \
# ...

# %%
# Setting the Max Rows shown to None so I wil display all the rows

pd.set_option('display.max_rows', 10)

# %%
#This is going to show all of the unique values

df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# Building a Scatter plot with budget vs gross revenue


plt.scatter(x=df['budget'], y=df['gross'])
plt.show()

# %%
# Removing all of the negative values from the gross column
df = df[df.gross >= 0]

# %%
plt.scatter(x=df['budget'], y=df['gross'])
plt.show()

# %%
# Building a Scatter plot with budget vs gross revenue
# Naming the X and Y axis so its a bit easier to read what is going on in the graph

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')
plt.show()

# %%
# Plot the budget vs gross using Seasborn
# Creating a regression plot

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int32
# released     object
# score       float64
# votes         int32
# director     object
# writer       object
# star         object
# country      object
# budget        int32
# gross         int32
# company      object
# runtime     float64
# dtype: object

# %%
# Originally received an error when trying to create a correlation matrix so I had to
# Tell the dataframe to only include integers and floats when trying to create the matrix

numeric_df = df.select_dtypes(include=['float64', 'int64', 'int32'])
correlation_matrix = numeric_df.corr()

# %%
correlation_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.061303  0.203070  0.320740  0.277989  0.074460
# score    0.061303  1.000000  0.473405  0.067334  0.221701  0.412577
# votes    0.203070  0.473405  1.000000  0.431864  0.613791  0.345443
# budget   0.320740  0.067334  0.431864  1.000000  0.743536  0.311063
# gross    0.277989  0.221701  0.613791  0.743536  1.000000  0.261947
# runtime  0.074460  0.412577  0.345443  0.311063  0.261947  1.000000

# %%
# Visualizing the correlation matrix

correlation_matrix = numeric_df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Looking at the correlation between the company and the gross

df_numerized = df.copy()

for col_name in df_numerized.columns:
    if df_numerized[col_name].dtype == 'object':
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 6663  3641       5      0  2015       528    7.8   876000       768    1806
# 7244   387       5      0  2018       144    8.4   897000       105     513
# 7480  4386       4      2  2019      1125    6.9   222000      1012    1361
# 6653  2115       5      0  2015      1302    7.0   593000       335    2523
# 6043  3876       5      0  2012      1898    8.0  1300000      1060    1646
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 5640  3792       6      6  2015       889    5.8     3500       585    2924
# 2434  2967       5      0  1994      1466    4.5     1900      1805    3102
# 3681  1593       3      6  2001      1720    6.8    43000       952    1683
# 272   2907       6      9  1982      1524    3.9     2300       261      55
# 3203  4963       5      4  1997      2151    5.7     5800       651     161
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5640                                 Tanner Hall          R      Drama  2015
# 2434                  Philadelphia Experiment II      PG-13     Action  1994
# 3681                                Ginger Snaps  Not Rated      Drama  2001
# 272                                     Parasite          R     Horror  1982
# 3203                                  Trojan War      PG-13     Comedy  1997
#
# ...

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029317  0.010041  0.026328 -0.006593  0.015062
# rating   -0.029317  1.000000  0.147796  0.022102  0.017957  0.066235
# genre     0.010041  0.147796  1.000000 -0.068569  0.021763  0.035701
# year      0.026328  0.022102 -0.068569  1.000000 -0.005485  0.061303
# released -0.006593  0.017957  0.021763 -0.005485  1.000000  0.047067
# score     0.015062  0.066235  0.035701  0.061303  0.047067  1.000000
# votes     0.013925  0.006672 -0.135750  0.203070  0.032279  0.473405
# director  0.014821  0.014561 -0.008950 -0.036897  0.001683  0.006277
# writer    0.012562 -0.003229  0.017288 -0.025128  0.007586  0.013533
# star     -0.006365  0.009295  0.003795 -0.033130  0.016275  0.006530
# country  -0.025411  0.008271 -0.009073 -0.073711 -0.017016 -0.043403
# budget    0.026016 -0.205162 -0.369849  0.320740  0.024001  0.067334
# gross     0.011162 -0.190168 -0.252619  0.277989  0.018392  0.221701
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.029317
#           genre       0.010041
#           year        0.026328
#           released   -0.006593
#           score       0.015062
#           votes       0.013925
#           director    0.014821
#           writer      0.012562
#           star       -0.006365
#           country    -0.025411
#           budget      0.026016
#           gross       0.011162
#           company     0.021761
#           runtime     0.011560
# rating    name       -0.029317
#           rating      1.000000
#           genre       0.147796
#           year        0.022102
#           released    0.017957
#           score       0.066235
#           votes       0.006672
#           director    0.014561
#           writer     -0.003229
#           star        0.009295
#           country     0.008271
#           budget     -0.205162
#           gross      -0.190168
#           company    -0.092285
#           runtime     0.141883
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget    genre      -0.369849
# genre     budget     -0.369849
# gross     genre      -0.252619
# genre     gross      -0.252619
# budget    rating     -0.205162
# rating    budget     -0.205162
#           gross      -0.190168
# gross     rating     -0.190168
# genre     votes      -0.135750
# votes     genre      -0.135750
# rating    company    -0.092285
# company   rating     -0.092285
# year      country    -0.073711
# country   year       -0.073711
# genre     company    -0.071289
# company   genre      -0.071289
# genre     year       -0.068569
# year      genre      -0.068569
# runtime   genre      -0.058777
# genre     runtime    -0.058777
# country   score      -0.043403
# score     country    -0.043403
# writer    budget     -0.037460
# budget    writer     -0.037460
# year      director   -0.036897
# director  year       -0.036897
# runtime   country    -0.035374
# country   runtime    -0.035374
# year      star       -0.033130
# star      year       -0.033130
# ...

# %%
high_correlation = sorted_pairs[(sorted_pairs > 0.5)]

high_correlation
# Out:
# gross     votes       0.613791
# votes     gross       0.613791
# budget    gross       0.743536
# gross     budget      0.743536
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
